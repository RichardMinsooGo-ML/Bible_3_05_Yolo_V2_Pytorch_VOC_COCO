# %% [markdown]
# ## Check GPU

# %%
# Check GPU Type
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
    print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
    print('and then re-execute this cell.')
else:
    print(gpu_info)
    
# Memory Space
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
    print('To enable a high-RAM runtime, select the Runtime > "Change runtime type"')
    print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
    print('re-execute this cell.')
else:
    print('You are using a high-RAM runtime!')
    

# !pip install terminaltables
# !pip install --upgrade --no-cache-dir gdown

from IPython.display import clear_output 
# clear_output()
# Out:
# Wed Jun 15 01:25:38 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Your runtime has 27.3 gigabytes of available RAM
#
# You are using a high-RAM runtime!
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting terminaltables
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Installing collected packages: terminaltables
# Successfully installed terminaltables-3.1.10
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gdown in /usr/local/lib/python3.7/dist-packages (4.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from gdown) (1.15.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.7/dist-packages (from gdown) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from gdown) (4.64.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from gdown) (3.7.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from gdown) (4.6.3)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (2022.5.18.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (3.0.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
# Clone from Github Repository
! git init .
! git remote add origin https://github.com/RichardMinsooGo-ML/Bible_3_05_Yolo_V2_Pytorch_VOC_COCO.git
# ! git pull origin master
! git pull origin main
# Out:
# Initialized empty Git repository in /content/.git/
# remote: Enumerating objects: 71, done.
# remote: Counting objects: 100% (71/71), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 71 (delta 32), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (71/71), done.
# From https://github.com/RichardMinsooGo-ML/Bible_3_05_Yolo_V2_Pytorch_VOC_COCO
#  * branch            main       -> FETCH_HEAD
#  * [new branch]      main       -> origin/main

# %%
"""
# Clone from Github Repository
! git init .
! git remote add origin https://github.com/uvipen/Yolo-v2-pytorch.git
! git pull origin master
# ! git pull origin main
"""
# Out:
# '\n# Clone from Github Repository\n! git init .\n! git remote add origin https://github.com/uvipen/Yolo-v2-pytorch.git\n! git pull origin master\n# ! git pull origin main\n'

# %%
# !wget http://images.cocodataset.org/zips/train2017.zip
# !wget http://images.cocodataset.org/zips/val2017.zip
# !wget http://images.cocodataset.org/zips/test2017.zip
# !wget http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# Out:
# --2022-06-15 01:25:47--  http://images.cocodataset.org/zips/train2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 54.231.136.209
# Connecting to images.cocodataset.org (images.cocodataset.org)|54.231.136.209|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19336861798 (18G) [application/zip]
# Saving to: ‘train2017.zip’
#
# train2017.zip       100%[===================>]  18.01G  13.2MB/s    in 23m 17s
#
# 2022-06-15 01:49:05 (13.2 MB/s) - ‘train2017.zip’ saved [19336861798/19336861798]
#
# --2022-06-15 01:49:05--  http://images.cocodataset.org/zips/val2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 54.231.172.81
# Connecting to images.cocodataset.org (images.cocodataset.org)|54.231.172.81|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 815585330 (778M) [application/zip]
# Saving to: ‘val2017.zip’
#
# val2017.zip         100%[===================>] 777.80M  8.29MB/s    in 85s
#
# 2022-06-15 01:50:30 (9.20 MB/s) - ‘val2017.zip’ saved [815585330/815585330]
#
# --2022-06-15 01:50:30--  http://images.cocodataset.org/zips/test2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.217.128.153
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.217.128.153|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6646970404 (6.2G) [application/zip]
# Saving to: ‘test2017.zip’
#
# test2017.zip        100%[===================>]   6.19G  13.3MB/s    in 7m 57s
#
# 2022-06-15 01:58:28 (13.3 MB/s) - ‘test2017.zip’ saved [6646970404/6646970404]
#
# --2022-06-15 01:58:28--  http://images.cocodataset.org/annotations/annotations_trainval2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.216.243.84
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.216.243.84|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 252907541 (241M) [application/zip]
# Saving to: ‘annotations_trainval2017.zip’
#
# annotations_trainva 100%[===================>] 241.19M  13.7MB/s    in 19s
#
# 2022-06-15 01:58:48 (12.6 MB/s) - ‘annotations_trainval2017.zip’ saved [252907541/252907541]

# %%
# !wget http://images.cocodataset.org/zips/train2017.zip
# !wget http://images.cocodataset.org/zips/train2014.zip
# Out:
# --2022-06-15 02:45:06--  http://images.cocodataset.org/zips/train2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 54.231.136.161
# Connecting to images.cocodataset.org (images.cocodataset.org)|54.231.136.161|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19336861798 (18G) [application/zip]
# Saving to: ‘train2017.zip’
#
# train2017.zip       100%[===================>]  18.01G  13.5MB/s    in 23m 16s
#
# 2022-06-15 03:08:22 (13.2 MB/s) - ‘train2017.zip’ saved [19336861798/19336861798]
#
# --2022-06-15 03:08:22--  http://images.cocodataset.org/zips/train2014.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.216.114.131
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.216.114.131|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13510573713 (13G) [application/zip]
# Saving to: ‘train2014.zip’
#
# train2014.zip       100%[===================>]  12.58G  13.4MB/s    in 16m 28s
#
# 2022-06-15 03:24:51 (13.0 MB/s) - ‘train2014.zip’ saved [13510573713/13510573713]

# %%
# !wget http://images.cocodataset.org/zips/train2014.zip
# !wget http://images.cocodataset.org/zips/val2014.zip
# !wget http://images.cocodataset.org/zips/test2014.zip
# !wget http://images.cocodataset.org/annotations/annotations_trainval2014.zip
# Out:
# --2022-06-15 01:58:48--  http://images.cocodataset.org/zips/train2014.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.216.8.75
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.216.8.75|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13510573713 (13G) [application/zip]
# Saving to: ‘train2014.zip’
#
# train2014.zip       100%[===================>]  12.58G  13.8MB/s    in 15m 54s
#
# 2022-06-15 02:14:43 (13.5 MB/s) - ‘train2014.zip’ saved [13510573713/13510573713]
#
# --2022-06-15 02:14:43--  http://images.cocodataset.org/zips/val2014.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.217.136.17
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.217.136.17|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6645013297 (6.2G) [application/zip]
# Saving to: ‘val2014.zip’
#
# val2014.zip         100%[===================>]   6.19G  13.8MB/s    in 7m 44s
#
# 2022-06-15 02:22:27 (13.7 MB/s) - ‘val2014.zip’ saved [6645013297/6645013297]
#
# --2022-06-15 02:22:27--  http://images.cocodataset.org/zips/test2014.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.217.226.105
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.217.226.105|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6660437059 (6.2G) [application/zip]
# Saving to: ‘test2014.zip’
#
# test2014.zip        100%[===================>]   6.20G  13.5MB/s    in 8m 7s
#
# 2022-06-15 02:30:34 (13.1 MB/s) - ‘test2014.zip’ saved [6660437059/6660437059]
#
# --2022-06-15 02:30:34--  http://images.cocodataset.org/annotations/annotations_trainval2014.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.217.95.153
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.217.95.153|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 252872794 (241M) [application/zip]
# Saving to: ‘annotations_trainval2014.zip’
#
# annotations_trainva 100%[===================>] 241.16M  13.5MB/s    in 19s
#
# 2022-06-15 02:30:54 (12.5 MB/s) - ‘annotations_trainval2014.zip’ saved [252872794/252872794]

# %%
! mkdir data
! mkdir trained_models

# %%
import os
os.mkdir('data/COCO')
os.mkdir('data/COCO/images')

# %%
os.mkdir('data/COCO/anno_pickle')

# %%
# !unzip "/content/train2017.zip" -d "/content/data/COCO/images"
# !unzip "/content/train2014.zip" -d "/content/data/COCO/images"

clear_output()

# %%
# ! rm -rf /content/data/COCO/annotations/annotations

# %%
# !unzip "/content/val2017.zip" -d "/content/data/COCO/images"
# !unzip "/content/val2014.zip" -d "/content/data/COCO/images"
# !unzip "/content/test2017.zip" -d "/content/data/COCO/images"
# !unzip "/content/test2014.zip" -d "/content/data/COCO/images"
clear_output()

# %%
# !unzip "/content/annotations_trainval2017.zip" -d "/content/data/COCO"
# !unzip "/content/annotations_trainval2014.zip" -d "/content/data/COCO"
# Out:
# Archive:  /content/annotations_trainval2017.zip
#   inflating: /content/data/COCO/annotations/instances_train2017.json
#   inflating: /content/data/COCO/annotations/instances_val2017.json
#   inflating: /content/data/COCO/annotations/captions_train2017.json
#   inflating: /content/data/COCO/annotations/captions_val2017.json
#   inflating: /content/data/COCO/annotations/person_keypoints_train2017.json
#   inflating: /content/data/COCO/annotations/person_keypoints_val2017.json
# Archive:  /content/annotations_trainval2014.zip
#   inflating: /content/data/COCO/annotations/instances_train2014.json
#   inflating: /content/data/COCO/annotations/instances_val2014.json
#   inflating: /content/data/COCO/annotations/person_keypoints_train2014.json
#   inflating: /content/data/COCO/annotations/person_keypoints_val2014.json
#   inflating: /content/data/COCO/annotations/captions_train2014.json
#   inflating: /content/data/COCO/annotations/captions_val2014.json

# %%
! python /content/convert_coco_data/convert_coco_to_pkl.py --type train2017
! python /content/convert_coco_data/convert_coco_to_pkl.py --type val2017
! python /content/convert_coco_data/convert_coco_to_pkl.py --type train2014
! python /content/convert_coco_data/convert_coco_to_pkl.py --type val2014
# Out:
# There are 0 invalid annotation(s)
# There are 0 invalid annotation(s)
# There are 0 invalid annotation(s)
# There are 0 invalid annotation(s)

# %%
! rm /content/train2017.zip
! rm /content/train2014.zip
! rm /content/annotations_trainval2014.zip
! rm /content/annotations_trainval2017.zip
! rm /content/test2014.zip
! rm /content/test2017.zip
! rm /content/val2014.zip
! rm /content/val2017.zip

# %%
! pip install tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorboardX in /usr/local/lib/python3.7/dist-packages (2.5.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (1.21.6)
# Requirement already satisfied: protobuf<=3.20.1,>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (3.17.3)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf<=3.20.1,>=3.8.0->tensorboardX) (1.15.0)

# %%
! python /content/code_train_coco.py --num_epoches 3 --pre_trained_model_type params
# Out:
# /content/src/yolo_net.py:90: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   output_2 = output_2.view(batch_size, int(num_channel / 4), height, 2, width, 2).contiguous()
# /content/src/yolo_net.py:92: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   output_2 = output_2.view(batch_size, -1, int(height / 2), int(width / 2))
# /content/src/loss.py:40: UserWarning: torch.range is deprecated and will be removed in a future release because its behavior is inconsistent with Python's range builtin. Instead, use torch.arange, which produces values in [start, end).
#   lin_x = torch.range(0, width - 1).repeat(height, 1).view(height * width)
# /content/src/loss.py:41: UserWarning: torch.range is deprecated and will be removed in a future release because its behavior is inconsistent with Python's range builtin. Instead, use torch.arange, which produces values in [start, end).
#   lin_y = torch.range(0, height - 1).repeat(width, 1).t().contiguous().view(height * width)
# /content/src/loss.py:61: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/IndexingUtils.h:28.)
#   tcls = tcls[cls_mask].view(-1).long()
# /content/src/loss.py:73: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/IndexingUtils.h:28.)
#   cls = cls[cls_mask].view(-1, self.num_classes)
# /usr/local/lib/python3.7/dist-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# /usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py:175: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ../aten/src/ATen/native/IndexingUtils.h:28.)
#   allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
# Epoch: 1/3, Iteration: 1/8278, Lr: 1e-05, Loss:287.44 (Coord:3.93 Conf:237.27 Cls:46.24)
# Epoch: 1/3, Iteration: 2/8278, Lr: 1e-05, Loss:282.62 (Coord:3.44 Conf:225.68 Cls:53.50)
# Epoch: 1/3, Iteration: 3/8278, Lr: 1e-05, Loss:292.07 (Coord:5.54 Conf:202.35 Cls:84.18)
# Epoch: 1/3, Iteration: 4/8278, Lr: 1e-05, Loss:238.91 (Coord:3.46 Conf:173.78 Cls:61.68)
# Epoch: 1/3, Iteration: 5/8278, Lr: 1e-05, Loss:211.26 (Coord:5.04 Conf:141.06 Cls:65.17)
# Epoch: 1/3, Iteration: 6/8278, Lr: 1e-05, Loss:166.34 (Coord:4.14 Conf:112.31 Cls:49.89)
# Epoch: 1/3, Iteration: 7/8278, Lr: 1e-05, Loss:139.96 (Coord:3.65 Conf:86.18 Cls:50.13)
# Epoch: 1/3, Iteration: 8/8278, Lr: 1e-05, Loss:111.58 (Coord:2.93 Conf:64.79 Cls:43.86)
# Epoch: 1/3, Iteration: 9/8278, Lr: 1e-05, Loss:99.60 (Coord:3.70 Conf:48.05 Cls:47.85)
# Epoch: 1/3, Iteration: 10/8278, Lr: 1e-05, Loss:106.69 (Coord:4.96 Conf:36.53 Cls:65.19)
# Epoch: 1/3, Iteration: 11/8278, Lr: 1e-05, Loss:89.17 (Coord:3.81 Conf:27.15 Cls:58.21)
# Epoch: 1/3, Iteration: 12/8278, Lr: 1e-05, Loss:59.71 (Coord:2.00 Conf:18.97 Cls:38.74)
# Epoch: 1/3, Iteration: 13/8278, Lr: 1e-05, Loss:91.83 (Coord:4.19 Conf:17.12 Cls:70.51)
# Epoch: 1/3, Iteration: 14/8278, Lr: 1e-05, Loss:59.97 (Coord:2.42 Conf:13.19 Cls:44.36)
# Epoch: 1/3, Iteration: 15/8278, Lr: 1e-05, Loss:66.58 (Coord:2.86 Conf:9.99 Cls:53.72)
# Epoch: 1/3, Iteration: 16/8278, Lr: 1e-05, Loss:64.05 (Coord:3.15 Conf:9.58 Cls:51.32)
# Epoch: 1/3, Iteration: 17/8278, Lr: 1e-05, Loss:53.24 (Coord:2.92 Conf:8.28 Cls:42.03)
# Epoch: 1/3, Iteration: 18/8278, Lr: 1e-05, Loss:75.72 (Coord:4.54 Conf:7.11 Cls:64.07)
# Epoch: 1/3, Iteration: 19/8278, Lr: 1e-05, Loss:81.11 (Coord:4.45 Conf:8.99 Cls:67.67)
# Epoch: 1/3, Iteration: 20/8278, Lr: 1e-05, Loss:43.82 (Coord:3.01 Conf:6.64 Cls:34.17)
# Epoch: 1/3, Iteration: 21/8278, Lr: 1e-05, Loss:85.70 (Coord:4.83 Conf:6.12 Cls:74.75)
# Epoch: 1/3, Iteration: 22/8278, Lr: 1e-05, Loss:71.60 (Coord:3.19 Conf:7.18 Cls:61.23)
# Epoch: 1/3, Iteration: 23/8278, Lr: 1e-05, Loss:82.60 (Coord:3.68 Conf:7.51 Cls:71.41)
# Epoch: 1/3, Iteration: 24/8278, Lr: 1e-05, Loss:52.48 (Coord:2.13 Conf:5.44 Cls:44.92)
# Epoch: 1/3, Iteration: 25/8278, Lr: 1e-05, Loss:90.78 (Coord:4.57 Conf:8.64 Cls:77.57)
# Epoch: 1/3, Iteration: 26/8278, Lr: 1e-05, Loss:106.81 (Coord:4.86 Conf:9.53 Cls:92.43)
# Epoch: 1/3, Iteration: 27/8278, Lr: 1e-05, Loss:66.20 (Coord:3.59 Conf:6.55 Cls:56.05)
# Epoch: 1/3, Iteration: 28/8278, Lr: 1e-05, Loss:75.30 (Coord:3.24 Conf:8.45 Cls:63.61)
# Epoch: 1/3, Iteration: 29/8278, Lr: 1e-05, Loss:55.11 (Coord:2.48 Conf:6.98 Cls:45.64)
# Epoch: 1/3, Iteration: 30/8278, Lr: 1e-05, Loss:31.67 (Coord:1.39 Conf:4.71 Cls:25.57)
# Epoch: 1/3, Iteration: 31/8278, Lr: 1e-05, Loss:51.50 (Coord:2.36 Conf:4.91 Cls:44.23)
# Epoch: 1/3, Iteration: 32/8278, Lr: 1e-05, Loss:58.43 (Coord:3.49 Conf:5.09 Cls:49.85)
# Epoch: 1/3, Iteration: 33/8278, Lr: 1e-05, Loss:68.23 (Coord:3.21 Conf:6.05 Cls:58.97)
# Epoch: 1/3, Iteration: 34/8278, Lr: 1e-05, Loss:41.57 (Coord:2.06 Conf:4.84 Cls:34.67)
# Epoch: 1/3, Iteration: 35/8278, Lr: 1e-05, Loss:84.36 (Coord:4.32 Conf:6.94 Cls:73.10)
# Epoch: 1/3, Iteration: 36/8278, Lr: 1e-05, Loss:83.02 (Coord:4.17 Conf:7.61 Cls:71.23)
# Epoch: 1/3, Iteration: 37/8278, Lr: 1e-05, Loss:60.46 (Coord:3.84 Conf:5.86 Cls:50.77)
# Epoch: 1/3, Iteration: 38/8278, Lr: 1e-05, Loss:46.27 (Coord:2.02 Conf:5.74 Cls:38.51)
# Epoch: 1/3, Iteration: 39/8278, Lr: 1e-05, Loss:58.41 (Coord:3.05 Conf:4.35 Cls:51.01)
# Epoch: 1/3, Iteration: 40/8278, Lr: 1e-05, Loss:42.11 (Coord:1.92 Conf:3.90 Cls:36.28)
# Epoch: 1/3, Iteration: 41/8278, Lr: 1e-05, Loss:62.10 (Coord:3.20 Conf:5.17 Cls:53.72)
# Epoch: 1/3, Iteration: 42/8278, Lr: 1e-05, Loss:55.35 (Coord:3.89 Conf:6.23 Cls:45.23)
# Epoch: 1/3, Iteration: 43/8278, Lr: 1e-05, Loss:60.43 (Coord:2.83 Conf:7.49 Cls:50.10)
# Epoch: 1/3, Iteration: 44/8278, Lr: 1e-05, Loss:102.34 (Coord:5.83 Conf:8.16 Cls:88.35)
# Epoch: 1/3, Iteration: 45/8278, Lr: 1e-05, Loss:58.44 (Coord:3.19 Conf:6.16 Cls:49.10)
# Epoch: 1/3, Iteration: 46/8278, Lr: 1e-05, Loss:65.03 (Coord:3.18 Conf:5.87 Cls:55.98)
# Epoch: 1/3, Iteration: 47/8278, Lr: 1e-05, Loss:55.19 (Coord:3.35 Conf:6.00 Cls:45.84)
# Epoch: 1/3, Iteration: 48/8278, Lr: 1e-05, Loss:51.34 (Coord:3.31 Conf:6.01 Cls:42.02)
# Epoch: 1/3, Iteration: 49/8278, Lr: 1e-05, Loss:62.77 (Coord:3.51 Conf:5.96 Cls:53.30)
# Epoch: 1/3, Iteration: 50/8278, Lr: 1e-05, Loss:56.84 (Coord:3.29 Conf:5.96 Cls:47.59)
# Epoch: 1/3, Iteration: 51/8278, Lr: 1e-05, Loss:55.79 (Coord:3.35 Conf:5.27 Cls:47.17)
# Epoch: 1/3, Iteration: 52/8278, Lr: 1e-05, Loss:59.46 (Coord:3.15 Conf:5.45 Cls:50.87)
# Epoch: 1/3, Iteration: 53/8278, Lr: 1e-05, Loss:59.37 (Coord:3.62 Conf:5.73 Cls:50.02)
# Epoch: 1/3, Iteration: 54/8278, Lr: 1e-05, Loss:56.47 (Coord:4.07 Conf:4.99 Cls:47.41)
# Epoch: 1/3, Iteration: 55/8278, Lr: 1e-05, Loss:54.82 (Coord:2.94 Conf:4.94 Cls:46.94)
# Epoch: 1/3, Iteration: 56/8278, Lr: 1e-05, Loss:72.93 (Coord:4.04 Conf:7.68 Cls:61.20)
# Epoch: 1/3, Iteration: 57/8278, Lr: 1e-05, Loss:69.49 (Coord:3.25 Conf:5.60 Cls:60.65)
# Epoch: 1/3, Iteration: 58/8278, Lr: 1e-05, Loss:30.75 (Coord:1.60 Conf:3.84 Cls:25.31)
# Epoch: 1/3, Iteration: 59/8278, Lr: 1e-05, Loss:78.24 (Coord:3.94 Conf:9.58 Cls:64.72)
# Epoch: 1/3, Iteration: 60/8278, Lr: 1e-05, Loss:65.53 (Coord:2.98 Conf:7.02 Cls:55.54)
# Epoch: 1/3, Iteration: 61/8278, Lr: 1e-05, Loss:50.21 (Coord:2.80 Conf:5.30 Cls:42.12)
# Epoch: 1/3, Iteration: 62/8278, Lr: 1e-05, Loss:47.87 (Coord:2.95 Conf:4.32 Cls:40.60)
# Epoch: 1/3, Iteration: 63/8278, Lr: 1e-05, Loss:41.31 (Coord:2.36 Conf:4.45 Cls:34.50)
# Epoch: 1/3, Iteration: 64/8278, Lr: 1e-05, Loss:42.18 (Coord:2.47 Conf:4.44 Cls:35.28)
# Epoch: 1/3, Iteration: 65/8278, Lr: 1e-05, Loss:55.06 (Coord:2.68 Conf:6.45 Cls:45.93)
# Epoch: 1/3, Iteration: 66/8278, Lr: 1e-05, Loss:42.04 (Coord:1.98 Conf:4.73 Cls:35.33)
# Epoch: 1/3, Iteration: 67/8278, Lr: 1e-05, Loss:69.97 (Coord:3.80 Conf:6.47 Cls:59.71)
# Epoch: 1/3, Iteration: 68/8278, Lr: 1e-05, Loss:49.13 (Coord:2.77 Conf:5.31 Cls:41.06)
# Epoch: 1/3, Iteration: 69/8278, Lr: 1e-05, Loss:88.01 (Coord:5.31 Conf:6.75 Cls:75.95)
# Epoch: 1/3, Iteration: 70/8278, Lr: 1e-05, Loss:48.76 (Coord:2.98 Conf:4.58 Cls:41.21)
# Epoch: 1/3, Iteration: 71/8278, Lr: 1e-05, Loss:72.85 (Coord:4.01 Conf:7.43 Cls:61.40)
# Epoch: 1/3, Iteration: 72/8278, Lr: 1e-05, Loss:81.51 (Coord:4.95 Conf:7.19 Cls:69.37)
# Epoch: 1/3, Iteration: 73/8278, Lr: 1e-05, Loss:43.73 (Coord:2.22 Conf:4.66 Cls:36.85)
# Epoch: 1/3, Iteration: 74/8278, Lr: 1e-05, Loss:61.40 (Coord:3.66 Conf:6.98 Cls:50.76)
# Epoch: 1/3, Iteration: 75/8278, Lr: 1e-05, Loss:50.97 (Coord:2.46 Conf:4.92 Cls:43.60)
# Epoch: 1/3, Iteration: 76/8278, Lr: 1e-05, Loss:57.84 (Coord:4.08 Conf:5.73 Cls:48.03)
# Epoch: 1/3, Iteration: 77/8278, Lr: 1e-05, Loss:51.13 (Coord:3.16 Conf:5.15 Cls:42.83)
# Epoch: 1/3, Iteration: 78/8278, Lr: 1e-05, Loss:43.67 (Coord:2.83 Conf:5.41 Cls:35.44)
# Epoch: 1/3, Iteration: 79/8278, Lr: 1e-05, Loss:49.72 (Coord:2.85 Conf:6.26 Cls:40.61)
# Epoch: 1/3, Iteration: 80/8278, Lr: 1e-05, Loss:77.98 (Coord:5.03 Conf:7.05 Cls:65.90)
# Epoch: 1/3, Iteration: 81/8278, Lr: 1e-05, Loss:46.77 (Coord:2.68 Conf:3.95 Cls:40.14)
# Epoch: 1/3, Iteration: 82/8278, Lr: 1e-05, Loss:58.66 (Coord:3.06 Conf:6.02 Cls:49.58)
# Epoch: 1/3, Iteration: 83/8278, Lr: 1e-05, Loss:59.17 (Coord:2.90 Conf:6.86 Cls:49.41)
# Epoch: 1/3, Iteration: 84/8278, Lr: 1e-05, Loss:54.66 (Coord:2.98 Conf:5.66 Cls:46.03)
# Epoch: 1/3, Iteration: 85/8278, Lr: 1e-05, Loss:59.85 (Coord:3.10 Conf:6.20 Cls:50.56)
# Epoch: 1/3, Iteration: 86/8278, Lr: 1e-05, Loss:60.44 (Coord:2.95 Conf:5.04 Cls:52.45)
# Epoch: 1/3, Iteration: 87/8278, Lr: 1e-05, Loss:51.41 (Coord:2.78 Conf:6.76 Cls:41.87)
# Epoch: 1/3, Iteration: 88/8278, Lr: 1e-05, Loss:61.61 (Coord:3.81 Conf:5.44 Cls:52.36)
# Epoch: 1/3, Iteration: 89/8278, Lr: 1e-05, Loss:79.29 (Coord:4.45 Conf:7.60 Cls:67.25)
# Epoch: 1/3, Iteration: 90/8278, Lr: 1e-05, Loss:55.19 (Coord:3.54 Conf:5.25 Cls:46.40)
# Epoch: 1/3, Iteration: 91/8278, Lr: 1e-05, Loss:30.00 (Coord:1.12 Conf:3.86 Cls:25.01)
# Epoch: 1/3, Iteration: 92/8278, Lr: 1e-05, Loss:75.06 (Coord:4.19 Conf:8.34 Cls:62.54)
# Epoch: 1/3, Iteration: 93/8278, Lr: 1e-05, Loss:58.77 (Coord:3.29 Conf:5.88 Cls:49.59)
# Epoch: 1/3, Iteration: 94/8278, Lr: 1e-05, Loss:40.03 (Coord:2.63 Conf:5.31 Cls:32.09)
# Epoch: 1/3, Iteration: 95/8278, Lr: 1e-05, Loss:62.58 (Coord:4.01 Conf:5.09 Cls:53.47)
# Epoch: 1/3, Iteration: 96/8278, Lr: 1e-05, Loss:50.45 (Coord:3.01 Conf:6.08 Cls:41.36)
# Epoch: 1/3, Iteration: 97/8278, Lr: 1e-05, Loss:102.08 (Coord:5.43 Conf:10.38 Cls:86.26)
# Epoch: 1/3, Iteration: 98/8278, Lr: 1e-05, Loss:61.49 (Coord:3.21 Conf:6.10 Cls:52.17)
# Epoch: 1/3, Iteration: 99/8278, Lr: 1e-05, Loss:55.66 (Coord:2.66 Conf:7.20 Cls:45.81)
# Epoch: 1/3, Iteration: 100/8278, Lr: 1e-05, Loss:42.03 (Coord:2.48 Conf:4.06 Cls:35.49)
# Epoch: 1/3, Iteration: 101/8278, Lr: 1e-05, Loss:88.66 (Coord:4.04 Conf:8.34 Cls:76.28)
# Epoch: 1/3, Iteration: 102/8278, Lr: 1e-05, Loss:37.57 (Coord:2.02 Conf:4.73 Cls:30.83)
# Epoch: 1/3, Iteration: 103/8278, Lr: 1e-05, Loss:56.46 (Coord:2.66 Conf:5.36 Cls:48.44)
# Epoch: 1/3, Iteration: 104/8278, Lr: 1e-05, Loss:25.03 (Coord:1.68 Conf:3.29 Cls:20.06)
# Epoch: 1/3, Iteration: 105/8278, Lr: 1e-05, Loss:65.25 (Coord:4.86 Conf:5.80 Cls:54.59)
# Epoch: 1/3, Iteration: 106/8278, Lr: 1e-05, Loss:41.33 (Coord:1.82 Conf:5.38 Cls:34.14)
# Epoch: 1/3, Iteration: 107/8278, Lr: 1e-05, Loss:52.18 (Coord:2.73 Conf:5.07 Cls:44.39)
# Epoch: 1/3, Iteration: 108/8278, Lr: 1e-05, Loss:63.18 (Coord:3.02 Conf:5.51 Cls:54.64)
# Epoch: 1/3, Iteration: 109/8278, Lr: 1e-05, Loss:54.49 (Coord:3.07 Conf:5.89 Cls:45.52)
# Epoch: 1/3, Iteration: 110/8278, Lr: 1e-05, Loss:38.41 (Coord:3.02 Conf:5.04 Cls:30.35)
# Epoch: 1/3, Iteration: 111/8278, Lr: 1e-05, Loss:41.25 (Coord:2.74 Conf:4.88 Cls:33.64)
# Epoch: 1/3, Iteration: 112/8278, Lr: 1e-05, Loss:74.78 (Coord:3.62 Conf:8.40 Cls:62.76)
# Epoch: 1/3, Iteration: 113/8278, Lr: 1e-05, Loss:85.04 (Coord:4.51 Conf:8.74 Cls:71.79)
# Epoch: 1/3, Iteration: 114/8278, Lr: 1e-05, Loss:50.34 (Coord:2.79 Conf:5.64 Cls:41.92)
# Epoch: 1/3, Iteration: 115/8278, Lr: 1e-05, Loss:46.56 (Coord:2.82 Conf:4.45 Cls:39.30)
# Epoch: 1/3, Iteration: 116/8278, Lr: 1e-05, Loss:65.07 (Coord:4.11 Conf:5.55 Cls:55.42)
# Epoch: 1/3, Iteration: 117/8278, Lr: 1e-05, Loss:48.97 (Coord:2.86 Conf:6.58 Cls:39.53)
# Epoch: 1/3, Iteration: 118/8278, Lr: 1e-05, Loss:41.09 (Coord:2.37 Conf:4.84 Cls:33.88)
# Epoch: 1/3, Iteration: 119/8278, Lr: 1e-05, Loss:39.12 (Coord:2.73 Conf:3.85 Cls:32.55)
# Epoch: 1/3, Iteration: 120/8278, Lr: 1e-05, Loss:62.80 (Coord:4.63 Conf:7.20 Cls:50.96)
# Epoch: 1/3, Iteration: 121/8278, Lr: 1e-05, Loss:39.48 (Coord:2.20 Conf:3.69 Cls:33.60)
# Epoch: 1/3, Iteration: 122/8278, Lr: 1e-05, Loss:58.69 (Coord:3.78 Conf:6.32 Cls:48.58)
# Epoch: 1/3, Iteration: 123/8278, Lr: 1e-05, Loss:50.88 (Coord:2.72 Conf:6.54 Cls:41.62)
# Epoch: 1/3, Iteration: 124/8278, Lr: 1e-05, Loss:68.98 (Coord:3.94 Conf:8.31 Cls:56.73)
# Epoch: 1/3, Iteration: 125/8278, Lr: 1e-05, Loss:57.40 (Coord:3.47 Conf:5.25 Cls:48.69)
# Epoch: 1/3, Iteration: 126/8278, Lr: 1e-05, Loss:64.39 (Coord:3.70 Conf:5.51 Cls:55.18)
# Epoch: 1/3, Iteration: 127/8278, Lr: 1e-05, Loss:70.91 (Coord:3.28 Conf:7.69 Cls:59.94)
# Epoch: 1/3, Iteration: 128/8278, Lr: 1e-05, Loss:73.88 (Coord:3.94 Conf:8.60 Cls:61.34)
# Epoch: 1/3, Iteration: 129/8278, Lr: 1e-05, Loss:53.34 (Coord:3.17 Conf:6.16 Cls:44.01)
# Epoch: 1/3, Iteration: 130/8278, Lr: 1e-05, Loss:43.53 (Coord:2.53 Conf:4.89 Cls:36.12)
# Epoch: 1/3, Iteration: 131/8278, Lr: 1e-05, Loss:55.70 (Coord:5.12 Conf:6.40 Cls:44.18)
# Epoch: 1/3, Iteration: 132/8278, Lr: 1e-05, Loss:81.50 (Coord:5.34 Conf:7.08 Cls:69.08)
# Epoch: 1/3, Iteration: 133/8278, Lr: 1e-05, Loss:57.26 (Coord:3.31 Conf:5.42 Cls:48.53)
# Epoch: 1/3, Iteration: 134/8278, Lr: 1e-05, Loss:51.86 (Coord:2.87 Conf:5.50 Cls:43.49)
# Epoch: 1/3, Iteration: 135/8278, Lr: 1e-05, Loss:52.79 (Coord:2.60 Conf:6.25 Cls:43.94)
# Epoch: 1/3, Iteration: 136/8278, Lr: 1e-05, Loss:39.88 (Coord:3.41 Conf:3.72 Cls:32.76)
# Epoch: 1/3, Iteration: 137/8278, Lr: 1e-05, Loss:64.06 (Coord:4.58 Conf:6.88 Cls:52.59)
# Epoch: 1/3, Iteration: 138/8278, Lr: 1e-05, Loss:49.09 (Coord:2.36 Conf:5.31 Cls:41.42)
# Epoch: 1/3, Iteration: 139/8278, Lr: 1e-05, Loss:48.91 (Coord:2.91 Conf:5.30 Cls:40.70)
# Epoch: 1/3, Iteration: 140/8278, Lr: 1e-05, Loss:55.30 (Coord:2.70 Conf:6.58 Cls:46.02)
# Epoch: 1/3, Iteration: 141/8278, Lr: 1e-05, Loss:112.88 (Coord:6.26 Conf:10.67 Cls:95.96)
# Epoch: 1/3, Iteration: 142/8278, Lr: 1e-05, Loss:64.04 (Coord:3.04 Conf:5.94 Cls:55.06)
# Epoch: 1/3, Iteration: 143/8278, Lr: 1e-05, Loss:62.49 (Coord:2.87 Conf:7.05 Cls:52.57)
# Epoch: 1/3, Iteration: 144/8278, Lr: 1e-05, Loss:82.56 (Coord:3.71 Conf:8.97 Cls:69.88)
# Epoch: 1/3, Iteration: 145/8278, Lr: 1e-05, Loss:67.43 (Coord:4.08 Conf:6.53 Cls:56.82)
# Epoch: 1/3, Iteration: 146/8278, Lr: 1e-05, Loss:51.80 (Coord:2.80 Conf:4.33 Cls:44.68)
# Epoch: 1/3, Iteration: 147/8278, Lr: 1e-05, Loss:55.12 (Coord:3.31 Conf:5.84 Cls:45.96)
# Epoch: 1/3, Iteration: 148/8278, Lr: 1e-05, Loss:71.40 (Coord:4.23 Conf:6.08 Cls:61.09)
# Epoch: 1/3, Iteration: 149/8278, Lr: 1e-05, Loss:64.54 (Coord:3.37 Conf:7.02 Cls:54.16)
# Epoch: 1/3, Iteration: 150/8278, Lr: 1e-05, Loss:39.05 (Coord:2.09 Conf:3.90 Cls:33.06)
# Epoch: 1/3, Iteration: 151/8278, Lr: 1e-05, Loss:47.14 (Coord:1.90 Conf:6.67 Cls:38.58)
# Epoch: 1/3, Iteration: 152/8278, Lr: 1e-05, Loss:30.42 (Coord:1.77 Conf:3.39 Cls:25.26)
# Epoch: 1/3, Iteration: 153/8278, Lr: 1e-05, Loss:41.57 (Coord:2.05 Conf:4.83 Cls:34.70)
# Epoch: 1/3, Iteration: 154/8278, Lr: 1e-05, Loss:58.54 (Coord:3.46 Conf:6.63 Cls:48.44)
# Epoch: 1/3, Iteration: 155/8278, Lr: 1e-05, Loss:68.39 (Coord:3.09 Conf:8.04 Cls:57.27)
# Epoch: 1/3, Iteration: 156/8278, Lr: 1e-05, Loss:73.07 (Coord:4.14 Conf:7.51 Cls:61.42)
# Epoch: 1/3, Iteration: 157/8278, Lr: 1e-05, Loss:54.67 (Coord:3.13 Conf:5.21 Cls:46.33)
# Epoch: 1/3, Iteration: 158/8278, Lr: 1e-05, Loss:60.88 (Coord:2.86 Conf:7.25 Cls:50.77)
# Epoch: 1/3, Iteration: 159/8278, Lr: 1e-05, Loss:75.47 (Coord:3.05 Conf:8.22 Cls:64.20)
# Epoch: 1/3, Iteration: 160/8278, Lr: 1e-05, Loss:55.17 (Coord:2.76 Conf:6.15 Cls:46.26)
# Epoch: 1/3, Iteration: 161/8278, Lr: 1e-05, Loss:63.74 (Coord:2.79 Conf:9.82 Cls:51.13)
# Epoch: 1/3, Iteration: 162/8278, Lr: 1e-05, Loss:44.40 (Coord:3.01 Conf:5.93 Cls:35.46)
# Epoch: 1/3, Iteration: 163/8278, Lr: 1e-05, Loss:62.48 (Coord:3.62 Conf:8.25 Cls:50.61)
# Epoch: 1/3, Iteration: 164/8278, Lr: 1e-05, Loss:64.01 (Coord:3.21 Conf:6.44 Cls:54.36)
# Epoch: 1/3, Iteration: 165/8278, Lr: 1e-05, Loss:85.14 (Coord:5.76 Conf:7.57 Cls:71.81)
# Epoch: 1/3, Iteration: 166/8278, Lr: 1e-05, Loss:57.76 (Coord:2.95 Conf:6.48 Cls:48.34)
# Epoch: 1/3, Iteration: 167/8278, Lr: 1e-05, Loss:42.42 (Coord:1.79 Conf:4.92 Cls:35.71)
# Epoch: 1/3, Iteration: 168/8278, Lr: 1e-05, Loss:82.59 (Coord:3.98 Conf:8.22 Cls:70.38)
# Epoch: 1/3, Iteration: 169/8278, Lr: 1e-05, Loss:38.03 (Coord:1.90 Conf:4.20 Cls:31.94)
# Epoch: 1/3, Iteration: 170/8278, Lr: 1e-05, Loss:47.43 (Coord:2.36 Conf:5.21 Cls:39.86)
# Epoch: 1/3, Iteration: 171/8278, Lr: 1e-05, Loss:69.01 (Coord:4.64 Conf:7.00 Cls:57.38)
# Epoch: 1/3, Iteration: 172/8278, Lr: 1e-05, Loss:75.05 (Coord:4.75 Conf:7.37 Cls:62.93)
# Epoch: 1/3, Iteration: 173/8278, Lr: 1e-05, Loss:57.75 (Coord:3.45 Conf:6.91 Cls:47.40)
# Epoch: 1/3, Iteration: 174/8278, Lr: 1e-05, Loss:65.81 (Coord:2.92 Conf:7.83 Cls:55.06)
# Epoch: 1/3, Iteration: 175/8278, Lr: 1e-05, Loss:98.40 (Coord:6.33 Conf:10.30 Cls:81.76)
# Epoch: 1/3, Iteration: 176/8278, Lr: 1e-05, Loss:76.35 (Coord:4.57 Conf:7.93 Cls:63.85)
# Epoch: 1/3, Iteration: 177/8278, Lr: 1e-05, Loss:69.64 (Coord:4.13 Conf:8.58 Cls:56.93)
# Epoch: 1/3, Iteration: 178/8278, Lr: 1e-05, Loss:55.78 (Coord:3.03 Conf:7.11 Cls:45.64)
# Epoch: 1/3, Iteration: 179/8278, Lr: 1e-05, Loss:71.21 (Coord:4.00 Conf:8.32 Cls:58.89)
# Epoch: 1/3, Iteration: 180/8278, Lr: 1e-05, Loss:45.87 (Coord:2.56 Conf:6.35 Cls:36.97)
# Epoch: 1/3, Iteration: 181/8278, Lr: 1e-05, Loss:59.15 (Coord:2.72 Conf:7.16 Cls:49.27)
# Epoch: 1/3, Iteration: 182/8278, Lr: 1e-05, Loss:37.96 (Coord:2.15 Conf:4.50 Cls:31.30)
# Epoch: 1/3, Iteration: 183/8278, Lr: 1e-05, Loss:66.30 (Coord:4.39 Conf:5.98 Cls:55.93)
# Epoch: 1/3, Iteration: 184/8278, Lr: 1e-05, Loss:32.98 (Coord:1.96 Conf:4.04 Cls:26.99)
# Epoch: 1/3, Iteration: 185/8278, Lr: 1e-05, Loss:27.42 (Coord:1.42 Conf:4.28 Cls:21.72)
# Epoch: 1/3, Iteration: 186/8278, Lr: 1e-05, Loss:35.07 (Coord:1.97 Conf:5.02 Cls:28.08)
# Epoch: 1/3, Iteration: 187/8278, Lr: 1e-05, Loss:53.99 (Coord:3.53 Conf:5.81 Cls:44.66)
# Epoch: 1/3, Iteration: 188/8278, Lr: 1e-05, Loss:81.51 (Coord:4.17 Conf:9.63 Cls:67.71)
# Epoch: 1/3, Iteration: 189/8278, Lr: 1e-05, Loss:60.66 (Coord:2.84 Conf:7.68 Cls:50.15)
# Epoch: 1/3, Iteration: 190/8278, Lr: 1e-05, Loss:31.80 (Coord:1.71 Conf:4.33 Cls:25.76)
# Epoch: 1/3, Iteration: 191/8278, Lr: 1e-05, Loss:60.79 (Coord:3.59 Conf:5.23 Cls:51.98)
# Epoch: 1/3, Iteration: 192/8278, Lr: 1e-05, Loss:75.50 (Coord:4.50 Conf:8.61 Cls:62.39)
# Epoch: 1/3, Iteration: 193/8278, Lr: 1e-05, Loss:35.70 (Coord:1.44 Conf:4.30 Cls:29.97)
# Epoch: 1/3, Iteration: 194/8278, Lr: 1e-05, Loss:39.17 (Coord:2.38 Conf:4.61 Cls:32.17)
# Epoch: 1/3, Iteration: 195/8278, Lr: 1e-05, Loss:41.68 (Coord:2.27 Conf:5.55 Cls:33.87)
# Epoch: 1/3, Iteration: 196/8278, Lr: 1e-05, Loss:47.49 (Coord:2.27 Conf:4.62 Cls:40.60)
# Epoch: 1/3, Iteration: 197/8278, Lr: 1e-05, Loss:68.15 (Coord:3.86 Conf:7.29 Cls:57.00)
# Epoch: 1/3, Iteration: 198/8278, Lr: 1e-05, Loss:50.34 (Coord:3.13 Conf:6.66 Cls:40.56)
# Epoch: 1/3, Iteration: 199/8278, Lr: 1e-05, Loss:45.61 (Coord:2.62 Conf:5.26 Cls:37.73)
# Epoch: 1/3, Iteration: 200/8278, Lr: 1e-05, Loss:46.08 (Coord:3.19 Conf:5.33 Cls:37.57)
# Epoch: 1/3, Iteration: 201/8278, Lr: 1e-05, Loss:53.20 (Coord:2.69 Conf:5.16 Cls:45.35)
# Epoch: 1/3, Iteration: 202/8278, Lr: 1e-05, Loss:47.33 (Coord:3.04 Conf:5.38 Cls:38.91)
# Epoch: 1/3, Iteration: 203/8278, Lr: 1e-05, Loss:64.84 (Coord:4.50 Conf:6.50 Cls:53.84)
# Epoch: 1/3, Iteration: 204/8278, Lr: 1e-05, Loss:32.46 (Coord:1.45 Conf:4.31 Cls:26.70)
# Epoch: 1/3, Iteration: 205/8278, Lr: 1e-05, Loss:66.05 (Coord:4.21 Conf:8.17 Cls:53.67)
# Epoch: 1/3, Iteration: 206/8278, Lr: 1e-05, Loss:72.88 (Coord:4.04 Conf:6.24 Cls:62.60)
# Epoch: 1/3, Iteration: 207/8278, Lr: 1e-05, Loss:49.17 (Coord:2.47 Conf:6.57 Cls:40.13)
# Epoch: 1/3, Iteration: 208/8278, Lr: 1e-05, Loss:55.25 (Coord:3.14 Conf:7.33 Cls:44.77)
# Epoch: 1/3, Iteration: 209/8278, Lr: 1e-05, Loss:54.70 (Coord:3.91 Conf:5.17 Cls:45.62)
# Epoch: 1/3, Iteration: 210/8278, Lr: 1e-05, Loss:69.28 (Coord:4.66 Conf:7.36 Cls:57.26)
# Epoch: 1/3, Iteration: 211/8278, Lr: 1e-05, Loss:71.47 (Coord:3.25 Conf:8.00 Cls:60.22)
# Epoch: 1/3, Iteration: 212/8278, Lr: 1e-05, Loss:76.31 (Coord:4.47 Conf:8.87 Cls:62.97)
# Epoch: 1/3, Iteration: 213/8278, Lr: 1e-05, Loss:43.69 (Coord:2.73 Conf:4.41 Cls:36.55)
# Epoch: 1/3, Iteration: 214/8278, Lr: 1e-05, Loss:51.80 (Coord:2.95 Conf:5.64 Cls:43.21)
# Epoch: 1/3, Iteration: 215/8278, Lr: 1e-05, Loss:35.44 (Coord:3.13 Conf:4.38 Cls:27.93)
# Epoch: 1/3, Iteration: 216/8278, Lr: 1e-05, Loss:63.08 (Coord:2.89 Conf:6.87 Cls:53.32)
# Epoch: 1/3, Iteration: 217/8278, Lr: 1e-05, Loss:34.07 (Coord:1.95 Conf:5.26 Cls:26.87)
# Epoch: 1/3, Iteration: 218/8278, Lr: 1e-05, Loss:64.34 (Coord:3.26 Conf:5.74 Cls:55.34)
# Epoch: 1/3, Iteration: 219/8278, Lr: 1e-05, Loss:41.01 (Coord:2.11 Conf:4.97 Cls:33.94)
# Epoch: 1/3, Iteration: 220/8278, Lr: 1e-05, Loss:58.18 (Coord:3.44 Conf:6.20 Cls:48.55)
# Epoch: 1/3, Iteration: 221/8278, Lr: 1e-05, Loss:36.65 (Coord:1.83 Conf:4.37 Cls:30.44)
# Epoch: 1/3, Iteration: 222/8278, Lr: 1e-05, Loss:52.48 (Coord:2.29 Conf:6.23 Cls:43.96)
# Epoch: 1/3, Iteration: 223/8278, Lr: 1e-05, Loss:59.31 (Coord:2.88 Conf:7.32 Cls:49.11)
# Epoch: 1/3, Iteration: 224/8278, Lr: 1e-05, Loss:75.36 (Coord:3.26 Conf:9.72 Cls:62.38)
# Epoch: 1/3, Iteration: 225/8278, Lr: 1e-05, Loss:42.54 (Coord:2.89 Conf:4.65 Cls:35.00)
# Epoch: 1/3, Iteration: 226/8278, Lr: 1e-05, Loss:65.39 (Coord:3.56 Conf:6.80 Cls:55.03)
# Epoch: 1/3, Iteration: 227/8278, Lr: 1e-05, Loss:71.81 (Coord:3.67 Conf:7.19 Cls:60.95)
# Epoch: 1/3, Iteration: 228/8278, Lr: 1e-05, Loss:39.48 (Coord:1.42 Conf:6.92 Cls:31.14)
# Epoch: 1/3, Iteration: 229/8278, Lr: 1e-05, Loss:35.64 (Coord:2.26 Conf:4.87 Cls:28.50)
# Epoch: 1/3, Iteration: 230/8278, Lr: 1e-05, Loss:67.29 (Coord:3.57 Conf:9.43 Cls:54.29)
# Epoch: 1/3, Iteration: 231/8278, Lr: 1e-05, Loss:50.64 (Coord:2.68 Conf:6.12 Cls:41.83)
# Epoch: 1/3, Iteration: 232/8278, Lr: 1e-05, Loss:45.39 (Coord:2.61 Conf:6.01 Cls:36.76)
# Epoch: 1/3, Iteration: 233/8278, Lr: 1e-05, Loss:42.54 (Coord:2.43 Conf:5.39 Cls:34.72)
# Epoch: 1/3, Iteration: 234/8278, Lr: 1e-05, Loss:40.04 (Coord:2.32 Conf:5.25 Cls:32.47)
# Epoch: 1/3, Iteration: 235/8278, Lr: 1e-05, Loss:54.41 (Coord:3.11 Conf:6.88 Cls:44.41)
# Epoch: 1/3, Iteration: 236/8278, Lr: 1e-05, Loss:51.02 (Coord:2.15 Conf:6.13 Cls:42.74)
# Epoch: 1/3, Iteration: 237/8278, Lr: 1e-05, Loss:60.66 (Coord:3.30 Conf:7.03 Cls:50.32)
# Epoch: 1/3, Iteration: 238/8278, Lr: 1e-05, Loss:58.97 (Coord:2.88 Conf:5.96 Cls:50.13)
# Epoch: 1/3, Iteration: 239/8278, Lr: 1e-05, Loss:50.24 (Coord:2.71 Conf:5.25 Cls:42.27)
# Epoch: 1/3, Iteration: 240/8278, Lr: 1e-05, Loss:43.22 (Coord:2.05 Conf:5.50 Cls:35.67)
# Epoch: 1/3, Iteration: 241/8278, Lr: 1e-05, Loss:62.20 (Coord:3.51 Conf:7.81 Cls:50.88)
# Epoch: 1/3, Iteration: 242/8278, Lr: 1e-05, Loss:53.72 (Coord:2.85 Conf:7.23 Cls:43.64)
# Epoch: 1/3, Iteration: 243/8278, Lr: 1e-05, Loss:32.74 (Coord:2.37 Conf:4.63 Cls:25.74)
# Epoch: 1/3, Iteration: 244/8278, Lr: 1e-05, Loss:52.97 (Coord:2.65 Conf:7.74 Cls:42.58)
# Epoch: 1/3, Iteration: 245/8278, Lr: 1e-05, Loss:63.68 (Coord:3.74 Conf:6.21 Cls:53.72)
# Epoch: 1/3, Iteration: 246/8278, Lr: 1e-05, Loss:72.30 (Coord:5.02 Conf:9.10 Cls:58.18)
# Epoch: 1/3, Iteration: 247/8278, Lr: 1e-05, Loss:42.96 (Coord:2.06 Conf:5.04 Cls:35.86)
# Epoch: 1/3, Iteration: 248/8278, Lr: 1e-05, Loss:60.62 (Coord:3.19 Conf:6.40 Cls:51.04)
# Epoch: 1/3, Iteration: 249/8278, Lr: 1e-05, Loss:72.68 (Coord:4.61 Conf:7.10 Cls:60.97)
# Epoch: 1/3, Iteration: 250/8278, Lr: 1e-05, Loss:50.01 (Coord:3.17 Conf:6.98 Cls:39.86)
# Epoch: 1/3, Iteration: 251/8278, Lr: 1e-05, Loss:45.40 (Coord:3.18 Conf:5.30 Cls:36.92)
# Epoch: 1/3, Iteration: 252/8278, Lr: 1e-05, Loss:75.90 (Coord:5.25 Conf:7.74 Cls:62.91)
# Epoch: 1/3, Iteration: 253/8278, Lr: 1e-05, Loss:40.08 (Coord:2.70 Conf:4.50 Cls:32.88)
# Epoch: 1/3, Iteration: 254/8278, Lr: 1e-05, Loss:59.44 (Coord:2.99 Conf:7.32 Cls:49.13)
# Epoch: 1/3, Iteration: 255/8278, Lr: 1e-05, Loss:47.37 (Coord:3.36 Conf:5.71 Cls:38.31)
# Epoch: 1/3, Iteration: 256/8278, Lr: 1e-05, Loss:67.04 (Coord:4.59 Conf:7.46 Cls:54.99)
# Epoch: 1/3, Iteration: 257/8278, Lr: 1e-05, Loss:67.52 (Coord:3.53 Conf:8.44 Cls:55.55)
# Epoch: 1/3, Iteration: 258/8278, Lr: 1e-05, Loss:75.11 (Coord:4.58 Conf:8.27 Cls:62.26)
# Epoch: 1/3, Iteration: 259/8278, Lr: 1e-05, Loss:77.06 (Coord:3.88 Conf:8.72 Cls:64.45)
# Epoch: 1/3, Iteration: 260/8278, Lr: 1e-05, Loss:76.46 (Coord:4.28 Conf:6.83 Cls:65.35)
# Epoch: 1/3, Iteration: 261/8278, Lr: 1e-05, Loss:64.49 (Coord:3.08 Conf:7.78 Cls:53.64)
# Epoch: 1/3, Iteration: 262/8278, Lr: 1e-05, Loss:59.10 (Coord:4.16 Conf:6.06 Cls:48.88)
# Epoch: 1/3, Iteration: 263/8278, Lr: 1e-05, Loss:69.87 (Coord:3.22 Conf:9.28 Cls:57.36)
# Epoch: 1/3, Iteration: 264/8278, Lr: 1e-05, Loss:39.92 (Coord:1.91 Conf:5.09 Cls:32.91)

# %%
! python /content/code_train_coco_all.py --num_epoches 3 --pre_trained_model_type params
